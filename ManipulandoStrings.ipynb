# %% [markdown]
# <a href="https://colab.research.google.com/github/ABeatrizSC/Python/blob/main/ManipulandoStrings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#22
#criar um programa que leia o nome completo de uma pessoa e mostre:
#a) O nome com todas as letras maiúsculas
#b) O nome com todas minúsculas
#c) Quantas letras ao todo sem (considerar espaços)
#d) Quantas letras tem o primeiro nome

nome = str(input("Digite seu nome completo: "))
print("Seu nome em maiúsculas é: ".format(nome.upper()))
print("Seu nome em minúsculas é: ".format(nome.lower()))
print("Seu nome tem ao todo {} letras".format(len(nome) - nome.count(' '))) #qtidade de caracteres - qtidade de espaços
print("Seu primeiro nome tem {} letras.".format(nome.find(' '))) #conta até achar o primeiro espaço em branco
separa = nome.split() #colocar dentro de uma lista as cada palavra do nome separadas.
print("Seu primeiro nome é {} e ele tem {} letras.".format(separa[0], len(separa[0])))
# Out:
# Digite seu nome completo: João da Silva
# Seu nome em maiúsculas é:
# Seu nome em minúsculas é:
# Seu nome tem ao todo 11 letras
# Seu primeiro nome tem 4 letras.
# Seu primeiro nome é João e ele tem 4 letras.

# %%
#23
#Faça um programa que leia um número de 0 a 9999 e mostre na tela cada um dos dígitos separados.
#Ex: Digite um número: 1834
#unidade: 4
#dezena: 3
#centena: 8
#milhar: 1

numero = str(input("Digite um numero: "))
if len(numero) > 4:
    print("Numero invalido. Digite novamente.")
    numero = str(input("Digite um numero: "))
else:
    if len(numero) == 1:
        print("Unidade: {}".format(numero[0]))
    elif len(numero) == 2:
        print("Unidade: {}".format(numero[1]))
        print("Dezena: {}".format(numero[0]))

    elif len(numero) == 3:
        print("Unidade: {}".format(numero[2]))
        print("Dezena: {}".format(numero[1]))
        print("Centena: {}".format(numero[0]))

    elif len(numero) == 4:
        print("Unidade: {}".format(numero[3]))
        print("Dezena: {}".format(numero[2]))
        print("Centena: {}".format(numero[1]))
        print("Milhar: {}".format(numero[0]))

# %%
#24
#Crie um programa que diga se o nome de uma pessoa começa ou não com nome “Santos”.

nome = str(input("Digite seu nome: ")).strip() #receber um nome já retirando os espaaços vazios do começo e fim.
nome = nome.title() #Todas as primeiras letras em maiúsculas para não dar erro no 'if' - case sentitive.
separa = nome.split()
if separa[0] == 'Santos':
    print("Seu nome começa com Santos.")
else:
    print("Seu nome não começa com Santos.")

# %%
#25
#Crie um programa que leia o nome de uma pessoa e diga se ela tem “Silva” no nome.

nome = str(input("Digite seu nome: "))
nome = nome.title() #Todas as primeiras letras em maiúsculas para não dar erro no 'if' - case sentitive.
if 'Silva' in nome:
    print("Você tem Silva no nome.")
else:
    print("Você não tem Silva no nome.")

# %%
#26
#Faça um programa que leia uma frase pelo teclado e mostre:
#a) quantas vezes aparece a letra “A”
#b) em que posição ela aparece a primeira vez.
#c) em que posição ela aparece a última vez

frase = str(input("Digite uma frase: ")).strip()
frase = frase.upper() #todas em maiúsculo - case sensitive
print("A letra A aparee na frase {} vezes".format(frase.count('A')))
print("A letra A aparece a primeira vez na posição {}".format(frase.find('A')+1)) #+1 para começar no '1' e não no '0'
print("A última letra A aparece na posição {}".format(frase.rfind('A')+1)) #analisar a partir da DIREITA
# Out:
# Digite uma frase: a aranha arranha a rã
# A letra A aparee na frase 8 vezes
# A letra A aparece a primeira vez na posição 1
# A última letra A aparece na posição 18

# %%
#27
#Faça um programa que leia o nome completo de uma pessoa mostrando em seguida o primeiro e último nome separadamente.
#Ex: Ana Maria de Souza
#primeiro: Ana
#último: Souza

nome = str(input("Digite seu nome completo: "))
nomesep = nome.split()
print("Primeiro: {}".format(nomesep[0]))
ultimo = len(nomesep)
print("Ultimo: {}".format(nomesep[ultimo-1]))
