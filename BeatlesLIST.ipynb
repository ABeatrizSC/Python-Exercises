# %% [markdown]
# <a href="https://colab.research.google.com/github/ABeatrizSC/Python/blob/main/BeatlesLIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#passo 1: criar uma lista vazia com o nome beatles;
#passo 2: utilizar o método append() para adicionar os seguintes membros da banda à lista: John Lennon, Paul McCartney, e George Harrison;
#passo 3: utilizar o loop for e o método append() para solicitar ao utilizador que adicione os seguintes membros da banda à lista: Stu Sutcliffe, e Pete Best;
#passo 4: utilizar a instrução del para remover Stu Sutcliffe da lista;
#passo 5: utilizar o método insert() para adicionar Ringo Starr ao início da lista.

beatles = []
beatles.append ("John") 
beatles.append ("Paul")
beatles.append ("George")
# step 1
print("Step 1:", beatles)

for i in range (2):
   new = (input("Digite o novo membro:"))
   beatles.append(new)

# step 2
print("Step 2:", beatles)

del beatles [3]

# step 3
print("Step 3:", beatles)

beatles.insert(0, "Ringo Starr")

# step 4
print("Step 4:", beatles)

# testing list legth
print("The Fab", len(beatles))
# Out:
# Step 1: ['John', 'Paul', 'George']
# Digite o novo membro:a
# Digite o novo membro:b
# Step 2: ['John', 'Paul', 'George', 'a', 'b']
# Step 3: ['John', 'Paul', 'George', 'b']
# Step 4: ['Ringo Starr', 'John', 'Paul', 'George', 'b']
# The Fab 5
